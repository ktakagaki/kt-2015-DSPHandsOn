# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import medfilt, triang
from neo import io 
import gitInformation
import quantities as pq
import os

# %%
# %matplotlib inline

# %%
gitInformation.printInformation()
# Out:
# Information about this notebook
# ============================================================
# Date: 2015-12-04
# Python Version: 2.7.10 |Anaconda 2.4.0 (32-bit)| (default, Oct 28 2015, 14:01:20) [MSC v.1500 32 bit (Intel)]
# Git directory: C:\Users\Dominik\Documents\GitRep\kt-2015-DSPHandsOn\.git
# Current git SHA: d83b35fdcdbac98d4444c0599e18bb784d4fce29
# Remotes: fork, origin,
# Current branch: master
# fork remote URL: http://github.com/dowa4213/kt-2015-DSPHandsOn.git
# origin remote URL: https://github.com/ktakagaki/kt-2015-DSPHandsOn.git

# %%
cachedir = 'C:\\Users\\Dominik\\Documents\\GitRep\\kt-2015-DSPHandsOn\\MedianFilter\\Python\\07. Real Data'

# %%
NIO = io.NeuralynxIO(sessiondir = cachedir, cachedir = cachedir)
block = NIO.read_block(t_stops = 2500*pq.s,events=True)
seg = block.segments[0]
analogsignal = seg.analogsignalarrays[0]
# Out:
# C:\Anaconda2\lib\site-packages\quantities-0.10.1-py2.7.egg\quantities\quantity.py:379: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
# C:\Anaconda2\lib\site-packages\quantities-0.10.1-py2.7.egg\quantities\quantity.py:388: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
# C:\Anaconda2\lib\site-packages\neo-0.4.0.dev0-py2.7.egg\neo\io\neuralynxio.py:253: UserWarning: Substituted t_starts and t_stops in order to skip gap in recording session.
#   warnings.warn('Substituted t_starts and t_stops in order to skip gap in recording session.')
# C:\Anaconda2\lib\site-packages\neo-0.4.0.dev0-py2.7.egg\neo\io\neuralynxio.py:504: UserWarning: Analogsignalarray was shortened due to gap in recorded data  of file CSC1.ncs at packet id 133635
#   ' of file %s at packet id %i'%(filename_ncs,min(gap_packets)))

# %%
plt.figure(figsize=(30,7))
plt.plot(analogsignal.times.rescale(pq.ms), analogsignal.magnitude)
